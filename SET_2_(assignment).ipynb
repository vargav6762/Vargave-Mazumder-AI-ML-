# %% [markdown]
# <a href="https://colab.research.google.com/github/vargav6762/Vargave-Mazumder-AI-ML-/blob/main/SET_2_(assignment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('SET_1 (1).csv')

plt.figure(figsize=(10, 5))
plt.bar(df['month'], df['news_sold'], color='green')
plt.title('News Sold Per Month')
plt.xlabel('Month')
plt.ylabel('News Sold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

df['percentage_change'] = df['news_sold'].pct_change() * 100
print(df)

filtered_df = df[df['news_sold'] < 2000]
print(filtered_df)

quarter_map = {
    'January': 'Q1', 'February': 'Q1', 'March': 'Q1',
    'April': 'Q2', 'May': 'Q2', 'June': 'Q2',
    'July': 'Q3', 'August': 'Q3', 'September': 'Q3',
    'October': 'Q4', 'November': 'Q4', 'December': 'Q4'
}
df['quarter'] = df['month'].map(quarter_map)
quarterly_sales = df.groupby('quarter')['news_sold'].sum()
print(quarterly_sales)

average_sales = df['news_sold'].mean()
above_avg_df = df[df['news_sold'] > average_sales]
above_avg_df.to_csv('above_average_news_sales.csv', index=False)
print(above_avg_df)
# Out:
#         month  news_sold  percentage_change
# 0     January       4174                NaN
# 1    February       4507           7.977959
# 2       March       1860         -58.730863
# 3       April       2294          23.333333
# 4         May       2130          -7.149085
# 5        June       2095          -1.643192
# 6        July       4772         127.780430
# 7      August       4092         -14.249790
# 8   September       2638         -35.532747
# 9     October       3169          20.128886
# 10   November       1466         -53.739350
# 11   December       2238          52.660300
#        month  news_sold  percentage_change
# 2      March       1860         -58.730863
# 10  November       1466         -53.739350
# quarter
# Q1    10541
# Q2     6519
# Q3    11502
# Q4     6873
# Name: news_sold, dtype: int64
#       month  news_sold  percentage_change quarter
# 0   January       4174                NaN      Q1
# 1  February       4507           7.977959      Q1
# ...
